# %%
import pyfolio as pf
import pandas as pd
# %matplotlib inline

return_ser = pd.read_csv('.tumbler/test.csv')
return_ser['date'] = pd.to_datetime(return_ser['date'], format='%Y/%m/%d')
return_ser.set_index('date', inplace=True)

return_ser.head()
# Out:
#                zz500    zz1000      sz50    return
# date
# 2016-02-22  0.020772  0.020463  0.024827  0.022301
# 2016-02-23 -0.005443 -0.006006 -0.011851 -0.008175
# 2016-02-24  0.006679  0.000874  0.005847  0.004605
# 2016-02-25 -0.079363 -0.079151 -0.053291 -0.068870
# 2016-02-26  0.004068 -0.004644  0.011794  0.004545

# %%
print(return_ser['return'])
# Out:
# date
# 2016-02-22    0.022301
# 2016-02-23   -0.008175
# 2016-02-24    0.004605
# 2016-02-25   -0.068870
# 2016-02-26    0.004545
# Name: return, dtype: float64

# %%
pf.create_returns_tear_sheet(return_ser['return'])
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;"><th>Start date</th><td colspan=2>2016-02-22</td></tr>
#     <tr style="text-align: right;"><th>End date</th><td colspan=2>2016-02-26</td></tr>
#     <tr style="text-align: right;"><th>Total months</th><td colspan=2>0</td></tr>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Backtest</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Annual return</th>
#       <td>-91.27%</td>
#     </tr>
#     <tr>
#       <th>Cumulative returns</th>
#       <td>-4.723%</td>
#     </tr>
#     <tr>
#       <th>Annual volatility</th>
#       <td>55.75%</td>
#     </tr>
#     <tr>
#       <th>Sharpe ratio</th>
#       <td>-4.12</td>
#     </tr>
#     <tr>
#       <th>Calmar ratio</th>
#       <td>-12.64</td>
#     </tr>
#     <tr>
#       <th>Stability</th>
#       <td>0.75</td>
#     </tr>
#     <tr>
#       <th>Max drawdown</th>
#       <td>-7.223%</td>
#     </tr>
#     <tr>
# ...

# %%
fig = pf.create_returns_tear_sheet(return_ser['return'], return_fig=True)

# for ax in fig.axes:
#         ax.tick_params(
#         axis='x',           # changes apply to the x-axis
#         which='both',       # both major and minor ticks are affected
#         bottom=True,
#         top=False,
#         labelbottom=True)    # labels along the bottom edge are on
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;"><th>Start date</th><td colspan=2>2016-02-22</td></tr>
#     <tr style="text-align: right;"><th>End date</th><td colspan=2>2016-02-26</td></tr>
#     <tr style="text-align: right;"><th>Total months</th><td colspan=2>0</td></tr>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Backtest</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Annual return</th>
#       <td>-91.27%</td>
#     </tr>
#     <tr>
#       <th>Cumulative returns</th>
#       <td>-4.723%</td>
#     </tr>
#     <tr>
#       <th>Annual volatility</th>
#       <td>55.75%</td>
#     </tr>
#     <tr>
#       <th>Sharpe ratio</th>
#       <td>-4.12</td>
#     </tr>
#     <tr>
#       <th>Calmar ratio</th>
#       <td>-12.64</td>
#     </tr>
#     <tr>
#       <th>Stability</th>
#       <td>0.75</td>
#     </tr>
#     <tr>
#       <th>Max drawdown</th>
#       <td>-7.223%</td>
#     </tr>
#     <tr>
# ...
